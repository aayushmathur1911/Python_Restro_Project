# %%
# for making a programme for a restaurant-
import pandas as pd
print("\t\t\t WELCOME TO OUR RESTRO")
print("\t\t        SERVING TASTE SINCE 1990")
print('WE SERVE:-1.INDIAN, 2.ITALIAN')
a=int(input('Select the menu of items you want according to upper given numbers:-'))
if a==1:
    dict={"Items":["Dal Bati","Rajma Chawal","Kadi Pakoda","Dal Makahani","Fried Dal with roti"],"Price":[320,290,220,245,250]}
    df=pd.DataFrame(dict)
    print(df)
    price=[]
    items=[]
    cost_quantity=[]
    x=True
    while x:
        b1=int(input('Enter the item you want according to index number'))
        print('you have ordered for',dict["Items"][b1])
        items.append(dict["Items"][b1])
        b2=int(input('Enter the quantity of above ordered item:-'))
        c=dict['Price'][b1]
        price.append(c)
        d=b2*dict["Price"][b1]
        cost_quantity.append(d)
        e=sum(cost_quantity)
        # price.append(p)
        cost=sum(price)
        d=input('Want to order anything else write yes or no:-')
        
        if d=="no":
            break
    print("You have ordered:-",items)
    print("Price of items :-",price)
    print("Price of items according to quantity:-",cost_quantity)
    print("Final price with tax that is 10%:-",e+(e*0.1))
        
if a==2:
    dict={"Items":["Pizza","White Sauce Pasta","Red Sauce Pasta","Macroni","Garlic Bread"],"Price":[190,160,155,140,110]}
    df=pd.DataFrame(dict)
    print(df)
    items=[]
    cost=[]
    cost_quantity=[]
    x=True
    while x:
        a=int(input("Enter the item you want to eat according to the index numbers:-"))
        print("You have ordered for",dict["Items"][a])
        a1=int(input('Enter the quantity of the ordered item:-'))
        items.append(dict["Items"][a])
        price=dict["Price"][a]
        cost.append(price)
        cost_quan=a1*dict["Price"][a]
        cost_quantity.append(cost_quan)
        b1=sum(cost_quantity)
        b=input('Want to order anything else enter yes or no:-')
        if b=="no":
            break
    print("You have ordered:-",items)
    print("Respective Price of items you have ordered:-",cost)
    print("Price accroding to the quantity:-",cost_quantity)
    print("Final price after 10% tax:-",b1+(b1*0.1))
